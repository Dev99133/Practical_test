# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime



if __name__ == "__main__":

    tracker = ExpenseTracker("expenses.csv")

    while True:
        print("\n===== EXPENSE TRACKER MENU =====")
        print("1. Add Expense")
        print("2. View Summary")
        print("3. Filter Expenses")
        print("4. Generate Report")
        print("5. Visualize Data")
        print("6. Exit")

        choice = input("Enter your choice (1-6): ")

        if choice == "1":
            date = input("Enter date (YYYY-MM-DD): ")
            amount = float(input("Enter amount: "))
            category = input("Enter category: ")
            description = input("Enter description: ")

            tracker.add_expense(date, amount, category, description)

        elif choice == "2":
            tracker.get_summary()

        elif choice == "3":
            cat = input("Enter category to filter (or press Enter): ")
            print(tracker.filter_expenses(category=cat))

        elif choice == "4":
            tracker.generate_report()

        elif choice == "5":
            tracker.visualize_data()

        elif choice == "6":
            print("Thank you! Exiting program.")
            break

        else:
            print("Invalid choice! Try again.")

# ===============================
# Smart Expense Tracker Application
# ===============================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime


class ExpenseTracker:

    def __init__(self, csv_file):
        self.csv_file = csv_file
        self.df = pd.read_csv(r"C:\Users\om\Desktop\Data set\expenses.csv")
        self.df['Date'] = pd.to_datetime(self.df['Date'])

    # -------------------------------
    # 1. Add Expense (OOP + Validation)
    # -------------------------------
    def add_expense(self, date, amount, category, description):
        if amount <= 0:
            print("Amount must be positive.")
            return

        new_expense = {
            "Date": date,
            "Amount": amount,
            "Category": category,
            "Description": description
        }

        self.df = pd.concat([self.df, pd.DataFrame([new_expense])], ignore_index=True)
        self.df.to_csv(self.csv_file, index=False)
        print("Expense added successfully!")

    # -------------------------------
    # 2. Summary (NumPy + Pandas)
    # -------------------------------
    def get_summary(self):
        total = np.sum(self.df["Amount"])
        average = np.mean(self.df["Amount"])

        print("\n--- Expense Summary ---")
        print(f"Total Expense: ₹{total:.2f}")
        print(f"Average Expense: ₹{average:.2f}")

        print("\nCategory-wise Spending:")
        print(self.df.groupby("Category")["Amount"].sum())

    # -------------------------------
    # 3. Filter Expenses
    # -------------------------------
    def filter_expenses(self, category=None, start_date=None, end_date=None):
        filtered = self.df.copy()

        if category:
            filtered = filtered[filtered["Category"] == category]

        if start_date and end_date:
            filtered = filtered[
                (filtered["Date"] >= start_date) &
                (filtered["Date"] <= end_date)
            ]

        return filtered

    # -------------------------------
    # 4. Generate Report
    # -------------------------------
    def generate_report(self):
        print("\n--- Expense Report ---")
        self.get_summary()
        print("\nTop 5 Expenses:")
        print(self.df.sort_values("Amount", ascending=False).head())

    # -------------------------------
    # 5. Data Visualization
    # -------------------------------
    def visualize_data(self):

        # Bar Chart
        plt.figure()
        self.df.groupby("Category")["Amount"].sum().plot(kind="bar")
        plt.title("Total Expenses by Category")
        plt.xlabel("Category")
        plt.ylabel("Amount")
        plt.show()

        # Line Graph
        plt.figure()
        daily = self.df.groupby("Date")["Amount"].sum()
        daily.plot()
        plt.title("Spending Trend Over Time")
        plt.xlabel("Date")
        plt.ylabel("Amount")
        plt.show()

        # Pie Chart
        plt.figure()
        self.df.groupby("Category")["Amount"].sum().plot(kind="pie", autopct="%1.1f%%")
        plt.title("Expense Distribution by Category")
        plt.ylabel("")
        plt.show()

        # Histogram
        plt.figure()
        plt.hist(self.df["Amount"], bins=20)
        plt.title("Expense Amount Frequency")
        plt.xlabel("Amount")
        plt.ylabel("Frequency")
        plt.show()
# Out:
# ===== EXPENSE TRACKER MENU =====
# 1. Add Expense
# 2. View Summary
# 3. Filter Expenses
# 4. Generate Report
# 5. Visualize Data
# 6. Exit
# Enter your choice (1-6):  1
# Enter date (YYYY-MM-DD):  2025-12-25
# Enter amount:  50000
# Enter category:  prerita
# Enter description:  dev joshi
# Expense added successfully!
#
# ===== EXPENSE TRACKER MENU =====
# 1. Add Expense
# 2. View Summary
# 3. Filter Expenses
# 4. Generate Report
# 5. Visualize Data
# 6. Exit
# Enter your choice (1-6):  2
# --- Expense Summary ---
# Total Expense: ₹1278359.63
# Average Expense: ₹2551.62
#
# Category-wise Spending:
# Category
# Education        173735.54
# Entertainment    170451.66
# Food             212808.91
# Health           171267.55
# Shopping         168102.59
# Transport        189398.31
# Utilities        142595.07
# prerita           50000.00
# Name: Amount, dtype: float64
#
# ===== EXPENSE TRACKER MENU =====
# 1. Add Expense
# 2. View Summary
# 3. Filter Expenses
# 4. Generate Report
# 5. Visualize Data
# 6. Exit
# Enter your choice (1-6):  3
# Enter category to filter (or press Enter):  prerita
#            Date   Amount Category Description Payment_Mode Merchant Status  \
# 500  2025-12-25  50000.0  prerita   dev joshi          NaN      NaN    NaN
#
#     Month
# 500   NaN
#
# ===== EXPENSE TRACKER MENU =====
# 1. Add Expense
# 2. View Summary
# 3. Filter Expenses
# 4. Generate Report
# 5. Visualize Data
# 6. Exit
# Enter your choice (1-6):  3
# Enter category to filter (or press Enter):  Shopping
#                     Date   Amount  Category  Description Payment_Mode  \
# 0    2024-05-09 00:00:00  4526.27  Shopping    Expense 1         Cash
# 15   2024-08-26 00:00:00  3069.51  Shopping   Expense 16         Cash
# 48   2024-07-12 00:00:00  3626.79  Shopping   Expense 49          UPI
# 53   2024-09-24 00:00:00  3862.33  Shopping   Expense 54  Net Banking
# 63   2024-08-02 00:00:00  4048.83  Shopping   Expense 64   Debit Card
# ..                   ...      ...       ...          ...          ...
# 455  2024-04-01 00:00:00  3704.16  Shopping  Expense 456         Cash
# 456  2024-10-14 00:00:00  2181.88  Shopping  Expense 457          UPI
# 475  2024-06-27 00:00:00  2739.78  Shopping  Expense 476         Cash
# 482  2024-08-19 00:00:00   437.56  Shopping  Expense 483  Net Banking
# 494  2024-09-04 00:00:00  3497.69  Shopping  Expense 495  Credit Card
#
#         Merchant   Status      Month
# 0    Merchant_10  Pending        May
# 15   Merchant_19     Paid     August
# 48   Merchant_47     Paid       July
# 53   Merchant_37  Pending  September
# 63   Merchant_23  Pending     August
# ..           ...      ...        ...
# 455   Merchant_7     Paid      April
# 456  Merchant_34     Paid    October
# 475  Merchant_29     Paid       June
# 482  Merchant_29  Pending     August
# 494  Merchant_17  Pending  September
#
# [66 rows x 8 columns]
#
# ===== EXPENSE TRACKER MENU =====
# 1. Add Expense
# 2. View Summary
# 3. Filter Expenses
# 4. Generate Report
# 5. Visualize Data
# 6. Exit
# Enter your choice (1-6):  4
# --- Expense Report ---
#
# --- Expense Summary ---
# Total Expense: ₹1278359.63
# Average Expense: ₹2551.62
#
# Category-wise Spending:
# Category
# Education        173735.54
# Entertainment    170451.66
# Food             212808.91
# Health           171267.55
# Shopping         168102.59
# Transport        189398.31
# Utilities        142595.07
# prerita           50000.00
# Name: Amount, dtype: float64
#
# Top 5 Expenses:
#                     Date    Amount   Category  Description Payment_Mode  \
# 500           2025-12-25  50000.00    prerita    dev joshi          NaN
# 466  2024-06-21 00:00:00   4993.35  Transport  Expense 467  Credit Card
# 365  2024-03-31 00:00:00   4990.09  Education  Expense 366  Credit Card
# 331  2024-07-12 00:00:00   4985.56  Transport  Expense 332         Cash
# 463  2024-07-03 00:00:00   4985.38  Transport  Expense 464  Credit Card
#
#         Merchant   Status  Month
# 500          NaN      NaN    NaN
# 466  Merchant_22  Pending   June
# 365  Merchant_28     Paid  March
# 331  Merchant_49     Paid   July
# 463  Merchant_45  Pending   July
#
# ===== EXPENSE TRACKER MENU =====
# 1. Add Expense
# 2. View Summary
# 3. Filter Expenses
# 4. Generate Report
# 5. Visualize Data
# 6. Exit
# Enter your choice (1-6):  5
# ===== EXPENSE TRACKER MENU =====
# 1. Add Expense
# 2. View Summary
# 3. Filter Expenses
# 4. Generate Report
# 5. Visualize Data
# 6. Exit
